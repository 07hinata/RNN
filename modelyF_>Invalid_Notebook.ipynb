# %% [markdown]
# <a href="https://colab.research.google.com/github/07hinata/RNN/blob/main/modelyF_%3EInvalid_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# !pip install neuralforecast

print("✓")
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.7)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: neuralforecast in /usr/local/lib/python3.12/dist-packages (3.1.6)
# Requirement already satisfied: coreforecast>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (0.0.17)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (2025.3.0)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (2.0.2)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (2.2.2)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (2.10.0+cu128)
# Requirement already satisfied: tornado>=6.5.5 in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (6.5.5)
# Requirement already satisfied: pytorch-lightning>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (2.6.1)
# Requirement already satisfied: ray>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from ray[train,tune]>=2.2.0->neuralforecast) (2.54.1)
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (4.8.0)
# Requirement already satisfied: utilsforecast>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from neuralforecast) (0.2.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.5->neuralforecast) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.5->neuralforecast) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.5->neuralforecast) (2025.3)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.67.3)
# Requirement already satisfied: PyYAML>5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (6.0.3)
# Requirement already satisfied: torchmetrics>0.7.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (1.9.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (26.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.15.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (0.15.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (8.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (3.25.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (4.26.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (1.1.2)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (5.29.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2.32.4)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3 in /usr/local/lib/python3.12/dist-packages (from ray[train,tune]>=2.2.0->neuralforecast) (2.12.3)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.12/dist-packages (from ray[train,tune]>=2.2.0->neuralforecast) (2.6.5)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from ray[train,tune]>=2.2.0->neuralforecast) (18.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->neuralforecast) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.4.0->neuralforecast) (1.5.0)
# Requirement already satisfied: narwhals>=2.0 in /usr/local/lib/python3.12/dist-packages (from utilsforecast>=0.2.3->neuralforecast) (2.18.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna->neuralforecast) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna->neuralforecast) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna->neuralforecast) (2.0.48)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna->neuralforecast) (1.3.10)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (3.13.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[train,tune]>=2.2.0->neuralforecast) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[train,tune]>=2.2.0->neuralforecast) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[train,tune]>=2.2.0->neuralforecast) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->neuralforecast) (1.17.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna->neuralforecast) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->neuralforecast) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->neuralforecast) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (0.30.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->ray>=2.2.0->ray[train,tune]>=2.2.0->neuralforecast) (2026.2.25)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning>=2.0.0->neuralforecast) (1.23.0)
# ✓

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from neuralforecast import NeuralForecast
from neuralforecast.auto import AutoGRU, AutoLSTM

import warnings
warnings.filterwarnings('ignore')

horizon = 1096
window_size = 60

df = pd.read_csv('dly-0-203-0-11651-T.csv', names=['ID', 'STANICE', 'TYP', 'DT', 'VALUE', 'X', 'Y', 'Z'], skiprows=1)
df['DT'] = pd.to_datetime(df['DT'])
df = df[(df['TYP'] == 'AVG') & (df['DT'].between('2010-01-01', '2025-12-31'))].copy()
df = df.sort_values('DT').reset_index(drop=True)

final_results = []

print("✓")
# Out:
# ✓

# %%
df_nixtla = df[['DT', 'VALUE']].copy()
df_nixtla.columns = ['ds', 'y']
df_nixtla['unique_id'] = 'Svobodne_Dvory'

train_nixtla = df_nixtla[:-horizon]
test_nixtla = df_nixtla[-horizon:]

my_config = {
    "early_stop_patience_steps": 5,
    "max_steps": 100,
    "val_check_steps": 1
}

models_nixtla = [
    AutoGRU(h=horizon, config=my_config, num_samples=5),
    AutoLSTM(h=horizon, config=my_config, num_samples=5)
]

nf = NeuralForecast(models=models_nixtla, freq='D')
nf.fit(df=train_nixtla, val_size=horizon)
forecasts_neural = nf.predict()
forecasts_neural = forecasts_neural.merge(test_nixtla[['ds', 'y']], on='ds')

for mod in ['AutoGRU', 'AutoLSTM']:
    y_true = forecasts_neural['y']
    y_pred = forecasts_neural[mod]

    final_results.append({
        'Model': f'Nixtla-{mod}',
        'RMSE': np.sqrt(mean_squared_error(y_true, y_pred)),
        'R2': r2_score(y_true, y_pred),
        'MAE': mean_absolute_error(y_true, y_pred),
        'Predictions': y_pred.values
    })

print("✓")
# Out:
# 2026-04-10 12:10:43,755	INFO worker.py:2013 -- Started a local Ray instance.
# 2026-04-10 12:10:46,655	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# +--------------------------------------------------------------------+
# | Configuration for experiment     _train_tune_2026-04-10_12-10-31   |
# +--------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator             |
# | Scheduler                        FIFOScheduler                     |
# | Number of trials                 5                                 |
# +--------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/_train_tune_2026-04-10_12-10-31
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2026-04-10_12-10-31_380333_3796/artifacts/2026-04-10_12-10-46/_train_tune_2026-04-10_12-10-31/driver_artifacts`
# (_train_tune pid=4484) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=4484) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=4484)   warnings.warn(
# (_train_tune pid=4484) Seed set to 1
# (_train_tune pid=4484) GPU available: True (cuda), used: True
# (_train_tune pid=4484) TPU available: False, using: 0 TPU cores
# (_train_tune pid=4484) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=4484) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=4484) 2026-04-10 12:11:02.353260: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=4484) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=4484) E0000 00:00:1775823062.376948    4594 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=4484) E0000 00:00:1775823062.384541    4594 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=4484) W0000 00:00:1775823062.405969    4594 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4484) W0000 00:00:1775823062.406002    4594 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4484) W0000 00:00:1775823062.406005    4594 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4484) W0000 00:00:1775823062.406007    4594 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4484) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=4484) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=4484) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=4484) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=4484) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=4484) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=4484) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=4484) │ 3 │ hist_encoder │ GRU           │  363 K │ train │     0 │
# (_train_tune pid=4484) │ 4 │ mlp_decoder  │ MLP           │ 25.9 K │ train │     0 │
# (_train_tune pid=4484) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=4484) Trainable params: 388 K
# (_train_tune pid=4484) Non-trainable params: 0
# (_train_tune pid=4484) Total params: 388 K
# (_train_tune pid=4484) Total estimated model params size (MB): 1
# (_train_tune pid=4484) Modules in train mode: 10
# (_train_tune pid=4484) Modules in eval mode: 0
# (_train_tune pid=4484) Total FLOPs: 0
# (_train_tune pid=4484) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=4484) Epoch 16/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=4484)                                                               train_loss_step:
# (_train_tune pid=4484)                                                               0.514 valid_loss:
# (_train_tune pid=4484)                                                               3.544
# (_train_tune pid=4484)                                                               train_loss_epoch:
# (_train_tune pid=4484)                                                               0.514
# (_train_tune pid=4675) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=4675) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=4675)   warnings.warn(
# (_train_tune pid=4675) Seed set to 1
# (_train_tune pid=4675) GPU available: True (cuda), used: True
# (_train_tune pid=4675) TPU available: False, using: 0 TPU cores
# (_train_tune pid=4675) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=4675) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=4675) 2026-04-10 12:11:36.944179: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=4675) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=4675) E0000 00:00:1775823096.967231    4784 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=4675) E0000 00:00:1775823096.974959    4784 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=4675) W0000 00:00:1775823096.994865    4784 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4675) W0000 00:00:1775823096.994904    4784 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4675) W0000 00:00:1775823096.994909    4784 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4675) W0000 00:00:1775823096.994912    4784 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4675) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=4675) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=4675) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=4675) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=4675) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=4675) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=4675) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=4675) │ 3 │ hist_encoder │ GRU           │  363 K │ train │     0 │
# (_train_tune pid=4675) │ 4 │ mlp_decoder  │ MLP           │ 25.9 K │ train │     0 │
# (_train_tune pid=4675) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=4675) Trainable params: 388 K
# (_train_tune pid=4675) Non-trainable params: 0
# (_train_tune pid=4675) Total params: 388 K
# (_train_tune pid=4675) Total estimated model params size (MB): 1
# (_train_tune pid=4675) Modules in train mode: 10
# (_train_tune pid=4675) Modules in eval mode: 0
# (_train_tune pid=4675) Total FLOPs: 0
# (_train_tune pid=4675) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=4675) Epoch 16/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=4675)                                                               train_loss_step:
# (_train_tune pid=4675)                                                               0.514 valid_loss:
# (_train_tune pid=4675)                                                               3.544
# (_train_tune pid=4675)                                                               train_loss_epoch:
# (_train_tune pid=4675)                                                               0.514
# (_train_tune pid=4858) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=4858) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=4858)   warnings.warn(
# (_train_tune pid=4858) Seed set to 1
# (_train_tune pid=4858) GPU available: True (cuda), used: True
# (_train_tune pid=4858) TPU available: False, using: 0 TPU cores
# (_train_tune pid=4858) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=4858) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=4858) 2026-04-10 12:12:07.152524: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=4858) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=4858) E0000 00:00:1775823127.176376    4966 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=4858) E0000 00:00:1775823127.184165    4966 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=4858) W0000 00:00:1775823127.206583    4966 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4858) W0000 00:00:1775823127.206611    4966 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4858) W0000 00:00:1775823127.206614    4966 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4858) W0000 00:00:1775823127.206617    4966 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=4858) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=4858) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=4858) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=4858) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=4858) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=4858) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=4858) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=4858) │ 3 │ hist_encoder │ GRU           │  363 K │ train │     0 │
# (_train_tune pid=4858) │ 4 │ mlp_decoder  │ MLP           │ 25.9 K │ train │     0 │
# (_train_tune pid=4858) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=4858) Trainable params: 388 K
# (_train_tune pid=4858) Non-trainable params: 0
# (_train_tune pid=4858) Total params: 388 K
# (_train_tune pid=4858) Total estimated model params size (MB): 1
# (_train_tune pid=4858) Modules in train mode: 10
# (_train_tune pid=4858) Modules in eval mode: 0
# (_train_tune pid=4858) Total FLOPs: 0
# (_train_tune pid=4858) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=4858) Epoch 16/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=4858)                                                               train_loss_step:
# (_train_tune pid=4858)                                                               0.514 valid_loss:
# (_train_tune pid=4858)                                                               3.544
# (_train_tune pid=4858)                                                               train_loss_epoch:
# (_train_tune pid=4858)                                                               0.514
# (_train_tune pid=5040) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=5040) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=5040)   warnings.warn(
# (_train_tune pid=5040) Seed set to 1
# (_train_tune pid=5040) GPU available: True (cuda), used: True
# (_train_tune pid=5040) TPU available: False, using: 0 TPU cores
# (_train_tune pid=5040) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=5040) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=5040) 2026-04-10 12:12:38.197308: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=5040) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=5040) E0000 00:00:1775823158.236895    5142 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=5040) E0000 00:00:1775823158.248865    5142 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=5040) W0000 00:00:1775823158.278263    5142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5040) W0000 00:00:1775823158.278292    5142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5040) W0000 00:00:1775823158.278296    5142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5040) W0000 00:00:1775823158.278299    5142 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5040) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=5040) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=5040) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=5040) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=5040) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=5040) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=5040) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=5040) │ 3 │ hist_encoder │ GRU           │  363 K │ train │     0 │
# (_train_tune pid=5040) │ 4 │ mlp_decoder  │ MLP           │ 25.9 K │ train │     0 │
# (_train_tune pid=5040) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=5040) Trainable params: 388 K
# (_train_tune pid=5040) Non-trainable params: 0
# (_train_tune pid=5040) Total params: 388 K
# (_train_tune pid=5040) Total estimated model params size (MB): 1
# (_train_tune pid=5040) Modules in train mode: 10
# (_train_tune pid=5040) Modules in eval mode: 0
# (_train_tune pid=5040) Total FLOPs: 0
# (_train_tune pid=5040) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=5040) Epoch 16/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=5040)                                                               train_loss_step:
# (_train_tune pid=5040)                                                               0.514 valid_loss:
# (_train_tune pid=5040)                                                               3.544
# (_train_tune pid=5040)                                                               train_loss_epoch:
# (_train_tune pid=5040)                                                               0.514
# (_train_tune pid=5216) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=5216) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=5216)   warnings.warn(
# (_train_tune pid=5216) Seed set to 1
# (_train_tune pid=5216) GPU available: True (cuda), used: True
# (_train_tune pid=5216) TPU available: False, using: 0 TPU cores
# (_train_tune pid=5216) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=5216) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=5216) 2026-04-10 12:13:09.612259: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=5216) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=5216) E0000 00:00:1775823189.647990    5318 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=5216) E0000 00:00:1775823189.656643    5318 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=5216) W0000 00:00:1775823189.676758    5318 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5216) W0000 00:00:1775823189.676791    5318 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5216) W0000 00:00:1775823189.676795    5318 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5216) W0000 00:00:1775823189.676798    5318 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5216) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=5216) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=5216) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=5216) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=5216) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=5216) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=5216) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=5216) │ 3 │ hist_encoder │ GRU           │  363 K │ train │     0 │
# (_train_tune pid=5216) │ 4 │ mlp_decoder  │ MLP           │ 25.9 K │ train │     0 │
# (_train_tune pid=5216) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=5216) Trainable params: 388 K
# (_train_tune pid=5216) Non-trainable params: 0
# (_train_tune pid=5216) Total params: 388 K
# (_train_tune pid=5216) Total estimated model params size (MB): 1
# (_train_tune pid=5216) Modules in train mode: 10
# (_train_tune pid=5216) Modules in eval mode: 0
# (_train_tune pid=5216) Total FLOPs: 0
# (_train_tune pid=5216) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# 2026-04-10 12:13:23,890	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/_train_tune_2026-04-10_12-10-31' in 0.0065s.
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=5216) Epoch 16/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=5216)                                                               train_loss_step:
# (_train_tune pid=5216)                                                               0.514 valid_loss:
# (_train_tune pid=5216)                                                               3.544
# (_train_tune pid=5216)                                                               train_loss_epoch:
# (_train_tune pid=5216)                                                               0.514
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ loss         │ MAE           │      0 │ eval  │     0 │
# │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# │ 3 │ hist_encoder │ GRU           │  363 K │ train │     0 │
# │ 4 │ mlp_decoder  │ MLP           │ 25.9 K │ train │     0 │
# └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# Trainable params: 388 K
# Non-trainable params: 0
# Total params: 388 K
# Total estimated model params size (MB): 1
# Modules in train mode: 9
# Modules in eval mode: 1
# Total FLOPs: 0
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# +--------------------------------------------------------------------+
# | Configuration for experiment     _train_tune_2026-04-10_12-13-35   |
# +--------------------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator             |
# | Scheduler                        FIFOScheduler                     |
# | Number of trials                 5                                 |
# +--------------------------------------------------------------------+
#
# View detailed results here: /root/ray_results/_train_tune_2026-04-10_12-13-35
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2026-04-10_12-10-31_380333_3796/artifacts/2026-04-10_12-13-35/_train_tune_2026-04-10_12-13-35/driver_artifacts`
# (_train_tune pid=5443) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=5443) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=5443)   warnings.warn(
# (_train_tune pid=5443) Seed set to 1
# (_train_tune pid=5443) GPU available: True (cuda), used: True
# (_train_tune pid=5443) TPU available: False, using: 0 TPU cores
# (_train_tune pid=5443) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=5443) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=5443) 2026-04-10 12:13:50.259648: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=5443) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=5443) E0000 00:00:1775823230.283077    5538 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=5443) E0000 00:00:1775823230.290941    5538 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=5443) W0000 00:00:1775823230.310892    5538 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5443) W0000 00:00:1775823230.310919    5538 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5443) W0000 00:00:1775823230.310922    5538 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5443) W0000 00:00:1775823230.310924    5538 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5443) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=5443) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=5443) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=5443) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=5443) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=5443) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=5443) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=5443) │ 3 │ hist_encoder │ LSTM          │  199 K │ train │     0 │
# (_train_tune pid=5443) │ 4 │ mlp_decoder  │ MLP           │ 16.6 K │ train │     0 │
# (_train_tune pid=5443) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=5443) Trainable params: 215 K
# (_train_tune pid=5443) Non-trainable params: 0
# (_train_tune pid=5443) Total params: 215 K
# (_train_tune pid=5443) Total estimated model params size (MB): 0
# (_train_tune pid=5443) Modules in train mode: 10
# (_train_tune pid=5443) Modules in eval mode: 0
# (_train_tune pid=5443) Total FLOPs: 0
# (_train_tune pid=5443) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=5443) Epoch 22/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=5443)                                                               train_loss_step:
# (_train_tune pid=5443)                                                               0.511 valid_loss:
# (_train_tune pid=5443)                                                               3.548
# (_train_tune pid=5443)                                                               train_loss_epoch:
# (_train_tune pid=5443)                                                               0.511
# (_train_tune pid=5604) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=5604) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=5604)   warnings.warn(
# (_train_tune pid=5604) Seed set to 1
# (_train_tune pid=5604) GPU available: True (cuda), used: True
# (_train_tune pid=5604) TPU available: False, using: 0 TPU cores
# (_train_tune pid=5604) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=5604) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=5604) 2026-04-10 12:14:18.348355: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=5604) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=5604) E0000 00:00:1775823258.371109    5704 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=5604) E0000 00:00:1775823258.378502    5704 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=5604) W0000 00:00:1775823258.398446    5704 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5604) W0000 00:00:1775823258.398474    5704 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5604) W0000 00:00:1775823258.398476    5704 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5604) W0000 00:00:1775823258.398478    5704 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5604) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=5604) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=5604) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=5604) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=5604) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=5604) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=5604) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=5604) │ 3 │ hist_encoder │ LSTM          │  199 K │ train │     0 │
# (_train_tune pid=5604) │ 4 │ mlp_decoder  │ MLP           │ 16.6 K │ train │     0 │
# (_train_tune pid=5604) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=5604) Trainable params: 215 K
# (_train_tune pid=5604) Non-trainable params: 0
# (_train_tune pid=5604) Total params: 215 K
# (_train_tune pid=5604) Total estimated model params size (MB): 0
# (_train_tune pid=5604) Modules in train mode: 10
# (_train_tune pid=5604) Modules in eval mode: 0
# (_train_tune pid=5604) Total FLOPs: 0
# (_train_tune pid=5604) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=5604) Epoch 22/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=5604)                                                               train_loss_step:
# (_train_tune pid=5604)                                                               0.511 valid_loss:
# (_train_tune pid=5604)                                                               3.548
# (_train_tune pid=5604)                                                               train_loss_epoch:
# (_train_tune pid=5604)                                                               0.511
# (_train_tune pid=5764) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=5764) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=5764)   warnings.warn(
# (_train_tune pid=5764) Seed set to 1
# (_train_tune pid=5764) GPU available: True (cuda), used: True
# (_train_tune pid=5764) TPU available: False, using: 0 TPU cores
# (_train_tune pid=5764) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=5764) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=5764) 2026-04-10 12:14:46.372168: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=5764) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=5764) E0000 00:00:1775823286.394984    5867 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=5764) E0000 00:00:1775823286.403712    5867 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=5764) W0000 00:00:1775823286.423648    5867 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5764) W0000 00:00:1775823286.423674    5867 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5764) W0000 00:00:1775823286.423677    5867 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5764) W0000 00:00:1775823286.423679    5867 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5764) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=5764) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=5764) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=5764) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=5764) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=5764) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=5764) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=5764) │ 3 │ hist_encoder │ LSTM          │  199 K │ train │     0 │
# (_train_tune pid=5764) │ 4 │ mlp_decoder  │ MLP           │ 16.6 K │ train │     0 │
# (_train_tune pid=5764) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=5764) Trainable params: 215 K
# (_train_tune pid=5764) Non-trainable params: 0
# (_train_tune pid=5764) Total params: 215 K
# (_train_tune pid=5764) Total estimated model params size (MB): 0
# (_train_tune pid=5764) Modules in train mode: 10
# (_train_tune pid=5764) Modules in eval mode: 0
# (_train_tune pid=5764) Total FLOPs: 0
# (_train_tune pid=5764) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=5764) Epoch 22/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=5764)                                                               train_loss_step:
# (_train_tune pid=5764)                                                               0.511 valid_loss:
# (_train_tune pid=5764)                                                               3.548
# (_train_tune pid=5764)                                                               train_loss_epoch:
# (_train_tune pid=5764)                                                               0.511
# (_train_tune pid=5928) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=5928) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=5928)   warnings.warn(
# (_train_tune pid=5928) Seed set to 1
# (_train_tune pid=5928) GPU available: True (cuda), used: True
# (_train_tune pid=5928) TPU available: False, using: 0 TPU cores
# (_train_tune pid=5928) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=5928) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=5928) 2026-04-10 12:15:14.205815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=5928) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=5928) E0000 00:00:1775823314.230340    6030 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=5928) E0000 00:00:1775823314.239388    6030 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=5928) W0000 00:00:1775823314.259963    6030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5928) W0000 00:00:1775823314.259987    6030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5928) W0000 00:00:1775823314.259989    6030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5928) W0000 00:00:1775823314.259991    6030 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=5928) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=5928) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=5928) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=5928) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=5928) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=5928) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=5928) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=5928) │ 3 │ hist_encoder │ LSTM          │  199 K │ train │     0 │
# (_train_tune pid=5928) │ 4 │ mlp_decoder  │ MLP           │ 16.6 K │ train │     0 │
# (_train_tune pid=5928) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=5928) Trainable params: 215 K
# (_train_tune pid=5928) Non-trainable params: 0
# (_train_tune pid=5928) Total params: 215 K
# (_train_tune pid=5928) Total estimated model params size (MB): 0
# (_train_tune pid=5928) Modules in train mode: 10
# (_train_tune pid=5928) Modules in eval mode: 0
# (_train_tune pid=5928) Total FLOPs: 0
# (_train_tune pid=5928) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=5928) Epoch 22/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=5928)                                                               train_loss_step:
# (_train_tune pid=5928)                                                               0.511 valid_loss:
# (_train_tune pid=5928)                                                               3.548
# (_train_tune pid=5928)                                                               train_loss_epoch:
# (_train_tune pid=5928)                                                               0.511
# (_train_tune pid=6095) /usr/local/lib/python3.12/dist-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=6095) /usr/local/lib/python3.12/dist-packages/neuralforecast/common/_base_model.py:152: UserWarning: Input size too small. Automatically setting input size to 3 * horizon = 3288
# (_train_tune pid=6095)   warnings.warn(
# (_train_tune pid=6095) Seed set to 1
# (_train_tune pid=6095) GPU available: True (cuda), used: True
# (_train_tune pid=6095) TPU available: False, using: 0 TPU cores
# (_train_tune pid=6095) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=6095) `Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# (_train_tune pid=6095) 2026-04-10 12:15:42.367991: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (_train_tune pid=6095) WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# (_train_tune pid=6095) E0000 00:00:1775823342.390843    6202 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (_train_tune pid=6095) E0000 00:00:1775823342.398448    6202 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (_train_tune pid=6095) W0000 00:00:1775823342.417638    6202 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=6095) W0000 00:00:1775823342.417663    6202 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=6095) W0000 00:00:1775823342.417666    6202 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=6095) W0000 00:00:1775823342.417668    6202 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (_train_tune pid=6095) LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=6095) ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# (_train_tune pid=6095) ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# (_train_tune pid=6095) ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# (_train_tune pid=6095) │ 0 │ loss         │ MAE           │      0 │ train │     0 │
# (_train_tune pid=6095) │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# (_train_tune pid=6095) │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# (_train_tune pid=6095) │ 3 │ hist_encoder │ LSTM          │  199 K │ train │     0 │
# (_train_tune pid=6095) │ 4 │ mlp_decoder  │ MLP           │ 16.6 K │ train │     0 │
# (_train_tune pid=6095) └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# (_train_tune pid=6095) Trainable params: 215 K
# (_train_tune pid=6095) Non-trainable params: 0
# (_train_tune pid=6095) Total params: 215 K
# (_train_tune pid=6095) Total estimated model params size (MB): 0
# (_train_tune pid=6095) Modules in train mode: 10
# (_train_tune pid=6095) Modules in eval mode: 0
# (_train_tune pid=6095) Total FLOPs: 0
# (_train_tune pid=6095) /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# 2026-04-10 12:15:54,437	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/_train_tune_2026-04-10_12-13-35' in 0.0062s.
# INFO:lightning_fabric.utilities.seed:Seed set to 1
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# (_train_tune pid=6095) Epoch 22/-2 ━━━━━━━━━━━━━━━━━━ 1/1 0:00:00 • 0:00:00 0.00it/s v_num: 0.000
# (_train_tune pid=6095)                                                               train_loss_step:
# (_train_tune pid=6095)                                                               0.511 valid_loss:
# (_train_tune pid=6095)                                                               3.548
# (_train_tune pid=6095)                                                               train_loss_epoch:
# (_train_tune pid=6095)                                                               0.511
# ┏━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name         ┃ Type          ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ loss         │ MAE           │      0 │ eval  │     0 │
# │ 1 │ padder_train │ ConstantPad1d │      0 │ train │     0 │
# │ 2 │ scaler       │ TemporalNorm  │      0 │ train │     0 │
# │ 3 │ hist_encoder │ LSTM          │  199 K │ train │     0 │
# │ 4 │ mlp_decoder  │ MLP           │ 16.6 K │ train │     0 │
# └───┴──────────────┴───────────────┴────────┴───────┴───────┘
# Trainable params: 215 K
# Non-trainable params: 0
# Total params: 215 K
# Total estimated model params size (MB): 0
# Modules in train mode: 9
# Modules in eval mode: 1
# Total FLOPs: 0
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.rich_model_summary.RichModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(val_check_interval=1)` was configured so validation will run after every batch.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✓

# %%
data_b = df['VALUE'].values
train_b = data_b[:-horizon]
test_b = data_b[-horizon:]

scaler_b = MinMaxScaler(feature_range=(0, 1))
train_scaled_b = scaler_b.fit_transform(train_b.reshape(-1, 1))
test_scaled_b = scaler_b.transform(test_b.reshape(-1, 1))

def create_b_windows(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

test_combined_b = np.concatenate((train_scaled_b[-window_size:], test_scaled_b),
                                 axis=0)
X_train_b, y_train_b = create_b_windows(train_scaled_b, window_size)
X_test_b, y_test_b = create_b_windows(test_combined_b, window_size)

X_train_b = X_train_b.reshape(X_train_b.shape[0], X_train_b.shape[1], 1)
X_test_b = X_test_b.reshape(X_test_b.shape[0], X_test_b.shape[1], 1)

model_b = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(window_size, 1)),
    tf.keras.layers.LSTM(32),
    tf.keras.layers.Dense(1)
])

model_b.compile(optimizer='adam', loss='mse')
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3,
                                              restore_best_weights=True)
history_b = model_b.fit(X_train_b, y_train_b, epochs=100, batch_size=32,
                        validation_split=0.1, shuffle=False,
                        callbacks=[early_stop], verbose=1)

preds_b = model_b.predict(X_test_b)
preds_b_celsius = scaler_b.inverse_transform(preds_b).flatten()
y_true_b = scaler_b.inverse_transform(y_test_b.reshape(-1, 1)).flatten()

final_results.append({
    'Model': 'TF-LSTM-Base',
    'RMSE': np.sqrt(mean_squared_error(y_true_b, preds_b_celsius)),
    'R2': r2_score(y_true_b, preds_b_celsius),
    'MAE': mean_absolute_error(y_true_b, preds_b_celsius),
    'Predictions': preds_b_celsius
})

print("✓")
# Out:
# Epoch 1/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - loss: 0.0408 - val_loss: 0.0063
# Epoch 2/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0071 - val_loss: 0.0055
# Epoch 3/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0070 - val_loss: 0.0051
# Epoch 4/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0065 - val_loss: 0.0049
# Epoch 5/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0061 - val_loss: 0.0047
# Epoch 6/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 7/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0055 - val_loss: 0.0044
# Epoch 8/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0053 - val_loss: 0.0042
# Epoch 9/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0051 - val_loss: 0.0041
# Epoch 10/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0049 - val_loss: 0.0040
# Epoch 11/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - val_loss: 0.0038
# Epoch 12/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - val_loss: 0.0037
# Epoch 13/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0043 - val_loss: 0.0036
# Epoch 14/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0042 - val_loss: 0.0035
# Epoch 15/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 16/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 17/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 18/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 19/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 20/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 21/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 22/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 23/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 24/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 25/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0031 - val_loss: 0.0027
# Epoch 26/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 27/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 28/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 29/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 30/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 31/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 32/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0029 - val_loss: 0.0026
# Epoch 33/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 34/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 35/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 36/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 37/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 38/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 39/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 40/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 41/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 42/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 43/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 44/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 45/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 46/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 47/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 48/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 49/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 50/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 51/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 52/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 53/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 54/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 55/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 56/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 57/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 58/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 59/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 60/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 61/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0027 - val_loss: 0.0025
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ✓

# %%
df['day_of_year'] = df['DT'].dt.dayofyear
df['sin_day'] = np.sin(2 * np.pi * df['day_of_year'] / 365.25)
df['cos_day'] = np.cos(2 * np.pi * df['day_of_year'] / 365.25)
df['temp_roll_7'] = df['VALUE'].rolling(window=7).mean().fillna(method='bfill')
df['roll_diff'] = df['temp_roll_7'] - df['temp_roll_7'].shift(7).bfill()

features = ['VALUE', 'sin_day', 'cos_day', 'temp_roll_7', 'roll_diff']

data_c = df[features].values
train_c = data_c[:-horizon]
test_c = data_c[-horizon:]

scaler_c = MinMaxScaler(feature_range=(0, 1))
train_scaled_c = scaler_c.fit_transform(train_c)
test_scaled_c = scaler_c.transform(test_c)

def create_c_windows(data, window_size):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i, :])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

test_combined_c = np.concatenate((train_scaled_c[-window_size:], test_scaled_c),
                                 axis=0)
X_train_c, y_train_c = create_c_windows(train_scaled_c, window_size)
X_test_c, y_test_c = create_c_windows(test_combined_c, window_size)

model_c = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(window_size, len(features))),
    tf.keras.layers.LSTM(32, return_sequences=True),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.LSTM(16),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1)
])

model_c.compile(optimizer='adam', loss='mse')
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history_c = model_c.fit(X_train_c, y_train_c, epochs=100, batch_size=32, validation_split=0.1, shuffle=False, callbacks=[early_stop], verbose=1)

preds_c = model_c.predict(X_test_c)
simple_matrix = np.zeros((len(preds_c), len(features)))
simple_matrix[:, 0] = preds_c.flatten()
preds_c_celsius = scaler_c.inverse_transform(simple_matrix)[:, 0]
y_true_c = test_c[:, 0]

final_results.append({
    'Model': 'TF-LSTM-Complex',
    'RMSE': np.sqrt(mean_squared_error(y_true_c, preds_c_celsius)),
    'R2': r2_score(y_true_c, preds_c_celsius),
    'MAE': mean_absolute_error(y_true_c, preds_c_celsius),
    'Predictions': preds_c_celsius
})

print("✓")
# Out:
# Epoch 1/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0458 - val_loss: 0.0061
# Epoch 2/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0112 - val_loss: 0.0053
# Epoch 3/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0100 - val_loss: 0.0051
# Epoch 4/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0094 - val_loss: 0.0057
# Epoch 5/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0092 - val_loss: 0.0048
# Epoch 6/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0088 - val_loss: 0.0061
# Epoch 7/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082 - val_loss: 0.0048
# Epoch 8/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 0.0053
# Epoch 9/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - val_loss: 0.0049
# Epoch 10/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0075 - val_loss: 0.0054
# Epoch 11/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0074 - val_loss: 0.0054
# Epoch 12/100
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0069 - val_loss: 0.0051
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# ✓

# %%
print("\n" + "="*50)
print("SROVNÁVACÍ TABULKA PRO BAKALÁŘSKOU PRÁCI")
print("="*50)

df_final = pd.DataFrame(final_results).drop(columns=['Predictions'])
print(df_final.to_string(index=False))

plt.figure(figsize=(15, 7))
test_dates = df['DT'][-horizon:].values

plt.plot(test_dates[-horizon:], y_true_b[-horizon:], label='Skutečnost', color='black', lw=2)
for res in final_results:
    plt.plot(test_dates[-horizon:], res['Predictions'][-horizon:], label=res['Model'], alpha=0.8)

plt.title("Srovnání všech modelů v období 3 roky")
plt.ylabel("Teplota [°C]")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ==================================================
# SROVNÁVACÍ TABULKA PRO BAKALÁŘSKOU PRÁCI
# ==================================================
#           Model     RMSE       R2      MAE
#  Nixtla-AutoGRU 4.341231 0.695407 3.532604
# Nixtla-AutoLSTM 4.490662 0.674077 3.647970
#    TF-LSTM-Base 2.297377 0.914698 1.804546
# TF-LSTM-Complex 3.425518 0.810353 2.735215

# %%
def plot_learning_curves(history, title):
    plt.plot(history.history['loss'], label='Trénovací (Train Loss)', color='blue', lw=2)
    plt.plot(history.history['val_loss'], label='Validační (Val Loss)', color='red', lw=2, linestyle='--')
    plt.title(title)
    plt.xlabel('Epocha')
    plt.ylabel('Chyba (MSE)')
    plt.legend()
    plt.grid(True, alpha=0.3)

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plot_learning_curves(history_b, "Loss Curve: TF-LSTM-Base")

plt.subplot(1, 2, 2)
plot_learning_curves(history_c, "Loss Curve: TF-LSTM-Complex")

plt.tight_layout()
plt.show()

# %%
results_gru = nf.models[0].results.get_dataframe()
results_lstm = nf.models[1].results.get_dataframe()

existing_cols = ['loss', 'train_loss', 'time_total_s', 'training_iteration']

print("Výsledky 5 pokusů AutoGRU:")
print(results_gru[existing_cols].sort_values('loss'))

print("\nVýsledky 5 pokusů AutoLSTM:")
print(results_lstm[existing_cols].sort_values('loss'))
# Out:
# Výsledky 5 pokusů AutoGRU:
#        loss  train_loss  time_total_s  training_iteration
# 0  3.543794    0.513602     17.070524                  17
# 1  3.543794    0.513602     14.651688                  17
# 2  3.543794    0.513602     15.419417                  17
# 3  3.543794    0.513602     15.883586                  17
# 4  3.543794    0.513602     14.865222                  17
#
# Výsledky 5 pokusů AutoLSTM:
#        loss  train_loss  time_total_s  training_iteration
# 0  3.547831    0.510914     12.323622                  23
# 1  3.547831    0.510914     12.375461                  23
# 2  3.547831    0.510914     12.378953                  23
# 3  3.547831    0.510914     12.362991                  23
# 4  3.547831    0.510914     12.519870                  23

# %%
plt.figure(figsize=(15, 7))
last_year = 365

plt.plot(test_nixtla['ds'][-last_year:], test_nixtla['y'][-last_year:],
         label='Skutečnost (Realita)', color='black', lw=3, zorder=5)

for res in final_results:
    plt.plot(test_nixtla['ds'][-last_year:], res['Predictions'][-last_year:],
             label=res['Model'], alpha=0.7)

plt.title("Detailní srovnání modelů (Poslední 1 rok)", fontsize=16)
plt.xlabel("Datum")
plt.ylabel("Teplota [°C]")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 7))
last_days = 100

plt.plot(test_nixtla['ds'][-last_days:], test_nixtla['y'][-last_days:],
         label='Skutečnost (Realita)', color='black', lw=3, zorder=5)

for res in final_results:
    plt.plot(test_nixtla['ds'][-last_days:], res['Predictions'][-last_days:],
             label=res['Model'], alpha=0.7)

plt.title("Detailní srovnání modelů (Posledních 100 dní)", fontsize=16)
plt.xlabel("Datum")
plt.ylabel("Teplota [°C]")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
axes = axes.flatten()

for i, res in enumerate(final_results):
    if 'Nixtla' in res['Model']:
        y_actual = forecasts_neural['y'].values
    elif 'Base' in res['Model']:
        y_actual = y_true_b
    else:
        y_actual = y_true_c

    residuals = y_actual - res['Predictions']

    axes[i].scatter(y_actual, residuals, alpha=0.5, color='teal', s=10)

    axes[i].axhline(y=0, color='red', linestyle='--', lw=2)

    axes[i].set_title(f"Residua: {res['Model']}", fontsize=14)
    axes[i].set_xlabel("Skutečná teplota [°C]")
    axes[i].set_ylabel("Chyba (Skutečnost - Predikce)")
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.suptitle("Analýza residuí: Diagnostika systematických chyb", fontsize=16, y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

fig, axes = plt.subplots(2, 2, figsize=(15, 12))
axes = axes.flatten()

for i, res in enumerate(final_results):
    if 'Nixtla' in res['Model']:
        y_actual = forecasts_neural['y'].values
    elif 'Base' in res['Model']:
        y_actual = y_true_b
    else:
        y_actual = y_true_c

    errors = y_actual - res['Predictions']
    abs_errors = np.abs(errors)

    p80 = np.percentile(abs_errors, 80)

    sns.histplot(errors, bins=30, kde=True, ax=axes[i], color='royalblue', alpha=0.6)

    axes[i].axvline(x=0, color='red', linestyle='--', lw=2)
    axes[i].set_title(f"Rozdělení chyb: {res['Model']}\n(80 % chyb je menších než {p80:.1f} °C)", fontsize=13)
    axes[i].set_xlabel("Chyba v [°C] (Kladná = Model podstřelil)")
    axes[i].set_ylabel("Četnost")
    axes[i].grid(True, alpha=0.2)

plt.tight_layout()
plt.suptitle("Histogramy reziduí: Jak často se modely pletou?", fontsize=16, y=1.03)
plt.show()
